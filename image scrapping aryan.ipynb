# %%
from selenium import webdriver  # used
from selenium.webdriver.common.by import By  # used
import requests
import io
from PIL import Image
import pandas as pd
import numpy as np
from time import sleep  # used

# %%
def download_image(downloaded_path, url, file_name):
    image_content= requests.get(url).content  #actually getting the image
    image_file= io.BytesIO(image_content)     #converting the image into a bytes file
    image= Image.open(image_file)             #converting the image into an Pillow Image 
    file_path=downloaded_path + file_name

    with open(file_path,"wb") as f:
        image.save(f,"JPEG")

    print("Getting Images")

# %%
def get_amazon_image_link(url):
    driver = webdriver.Chrome()
    try:
        # Navigate to the Amazon product page
        driver.get(url)
        search_button= driver.find_element("xpath","//div[@id='imgTagWrapperId']/img")
        sleep(1)

        search_button.click()
        sleep(1)
        # Define the XPath for the image (update based on the actual HTML structure)
        xpath_expression = '//img[@class="fullscreen"]'

        # Find the image element using the XPath
        image_element = driver.find_element(By.XPATH, xpath_expression)

        # Extract the image URL
        if image_element:
            image_link = image_element.get_attribute('src')
            return image_link
        else:
            return "Image not found on the page."

    finally:
        # Close the browser window
        driver.quit()

# # Example usage
# amazon_url = "https://www.amazon.in/dp/B07BDNCTFC"
# image_url = get_amazon_image_link(amazon_url)

# download_image("/Users/aryansood/aims/nlp grup1/images/", image_url, "test.jpg")

# %%
df_path = r'/Users/aryansood/aims/nlp grup1/Data Input (Test & Train) copy.xlsx'
df = pd.read_excel(df_path,"Test_India", header=1)
df.describe()
list_of_names=list(df['ASIN'])
list_of_urls=list(df['URL'])

# for testing purposes only
# amazon_url = list_of_urls[3]
# image_url = get_amazon_image_link(amazon_url)

# download_image("/Users/aryansood/aims/nlp grup1/images/", image_url, "test.jpg")

# %%
for i in range(len(list_of_names)):
    try : 
        image_url = get_amazon_image_link(list_of_urls[i])
        image_name = list_of_names[i]
        download_image("/Users/aryansood/aims/nlp grup1/images/", image_url, image_name+".jpg")
    except : 
        print(f"ERROR IN WEBPAGE : {list_of_names[i]} + {list_of_urls[i]}")
    sleep(1)
        
print("DONE U FUCKING DUMBASS")
# Out:
# ERROR IN WEBPAGE : B08ZJXVL6D + https://www.amazon.in/dp/B08ZJXVL6D
# ERROR IN WEBPAGE : B0B6W5KCRM + https://www.amazon.in/dp/B0B6W5KCRM
# Getting Images
# ERROR IN WEBPAGE : B07K2JHVRY + https://www.amazon.in/dp/B07K2JHVRY
# Getting Images
# ERROR IN WEBPAGE : B07NDR2J4K + https://www.amazon.in/dp/B07NDR2J4K
# ERROR IN WEBPAGE : B0832ZWDHR + https://www.amazon.in/dp/B0832ZWDHR
# Getting Images
# ERROR IN WEBPAGE : B002ZVG95W + https://www.amazon.in/dp/B002ZVG95W
# ERROR IN WEBPAGE : B085RMP876 + https://www.amazon.in/dp/B085RMP876
# Getting Images
# ERROR IN WEBPAGE : B07BZN59BS + https://www.amazon.in/dp/B07BZN59BS
# ERROR IN WEBPAGE : B01412X46Y + https://www.amazon.in/dp/B01412X46Y
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 8
#       6     except :
#       7         print(f"ERROR IN WEBPAGE : {list_of_names[i]} + {list_of_urls[i]}")
# ...

# %%
print(len(list_of_names),len(list_of_urls))
# Out:
# 407 407

# %%
out="""ERROR IN WEBPAGE : B08ZJXVL6D + https://www.amazon.in/dp/B08ZJXVL6D
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
ERROR IN WEBPAGE : B09J5C7J7L + https://www.amazon.in/dp/B09J5C7J7L
Getting Images
ERROR IN WEBPAGE : B07BG1TX99 + https://www.amazon.in/dp/B07BG1TX99
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
ERROR IN WEBPAGE : B0BLKHG5BM + https://www.amazon.in/dp/B0BLKHG5BM
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
ERROR IN WEBPAGE : B08S34BGPY + https://www.amazon.in/dp/B08S34BGPY
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
ERROR IN WEBPAGE : B09RSKMZ9N + https://www.amazon.in/dp/B09RSKMZ9N
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
ERROR IN WEBPAGE : B09JBKB32P + https://www.amazon.in/dp/B09JBKB32P
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
ERROR IN WEBPAGE : B085WSTHJ3 + https://www.amazon.in/dp/B085WSTHJ3
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
ERROR IN WEBPAGE : B092LYQVNZ + https://www.amazon.in/dp/B092LYQVNZ
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
ERROR IN WEBPAGE : B09CMV2ZL1 + https://www.amazon.in/dp/B09CMV2ZL1
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
ERROR IN WEBPAGE : B0BD3X4D4P + https://www.amazon.in/dp/B0BD3X4D4P
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
ERROR IN WEBPAGE : B0BPGYR64D + https://www.amazon.in/dp/B0BPGYR64D
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
ERROR IN WEBPAGE : B09BSFVV6P + https://www.amazon.in/dp/B09BSFVV6P
ERROR IN WEBPAGE : B008KH6C1Q + https://www.amazon.in/dp/B008KH6C1Q
Getting Images
Getting Images
ERROR IN WEBPAGE : B0BC9WYNBC + https://www.amazon.in/dp/B0BC9WYNBC
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
ERROR IN WEBPAGE : B0BHHLHNL9 + https://www.amazon.in/dp/B0BHHLHNL9
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
ERROR IN WEBPAGE : B09HTV36RV + https://www.amazon.in/dp/B09HTV36RV
Getting Images
Getting Images
Getting Images
ERROR IN WEBPAGE : B09T9FSHL8 + https://www.amazon.in/dp/B09T9FSHL8
Getting Images
Getting Images
Getting Images
ERROR IN WEBPAGE : B08ZJXVL6D + https://www.amazon.in/dp/B08ZJXVL6D
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
ERROR IN WEBPAGE : B09D3JK2CB + https://www.amazon.in/dp/B09D3JK2CB
ERROR IN WEBPAGE : B0B82982CH + https://www.amazon.in/dp/B0B82982CH
ERROR IN WEBPAGE : B0C3HRZ53X + https://www.amazon.in/dp/B0C3HRZ53X
Getting Images
Getting Images
ERROR IN WEBPAGE : B093Y9LDPD + https://www.amazon.in/dp/B093Y9LDPD
Getting Images
Getting Images
Getting Images
Getting Images
ERROR IN WEBPAGE : B08JJBGZQH + https://www.amazon.in/dp/B08JJBGZQH
Getting Images
ERROR IN WEBPAGE : B07SWQWQGN + https://www.amazon.in/dp/B07SWQWQGN
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
ERROR IN WEBPAGE : B0B8JC1KDM + https://www.amazon.in/dp/B0B8JC1KDM
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
ERROR IN WEBPAGE : B09MFD21Y6 + https://www.amazon.in/dp/B09MFD21Y6
Getting Images
Getting Images
Getting Images
Getting Images
ERROR IN WEBPAGE : B0BRG6WH48 + https://www.amazon.in/dp/B0BRG6WH48
Getting Images
ERROR IN WEBPAGE : B07CG7NY3B + https://www.amazon.in/dp/B07CG7NY3B
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
ERROR IN WEBPAGE : B09HTVN8S4 + https://www.amazon.in/dp/B09HTVN8S4
Getting Images
Getting Images
ERROR IN WEBPAGE : B08KDXJ3CN + https://www.amazon.in/dp/B08KDXJ3CN
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
Getting Images
DONE U FUCKING DUMBASS"""
out = out.replace("\n"," ")
list1=out.split(" ")

# %%
list1
# Out:
# ['ERROR',
#  'IN',
#  'WEBPAGE',
#  ':',
#  'B08ZJXVL6D',
#  '+',
#  'https://www.amazon.in/dp/B08ZJXVL6D',
#  'Getting',
#  'Images',
#  'Getting',
#  'Images',
#  'Getting',
#  'Images',
#  'Getting',
#  'Images',
#  'Getting',
#  'Images',
#  'Getting',
#  'Images',
#  'Getting',
#  'Images',
#  'Getting',
#  'Images',
#  'Getting',
#  'Images',
#  'Getting',
#  'Images',
#  'Getting',
#  'Images',
#  'Getting',
#  'Images',
#  'Getting',
#  'Images',
#  'Getting',
#  'Images',
#  'Getting',
#  'Images',
#  'ERROR',
#  'IN',
#  'WEBPAGE',
#  ':',
#  'B09J5C7J7L',
#  '+',
#  'https://www.amazon.in/dp/B09J5C7J7L',
#  'Getting',
#  'Images',
#  'ERROR',
#  'IN',
#  'WEBPAGE',
#  ':',
#  'B07BG1TX99',
#  '+',
#  'https://www.amazon.in/dp/B07BG1TX99',
#  'Getting',
#  'Images',
#  'Getting',
#  'Images',
#  'Getting',
#  'Images',
#  'Getting',
#  'Images',
#  'Getting',
#  'Images',
#  'Getting',
#  'Images',
#  'Getting',
#  'Images',
#  'Getting',
#  'Images',
#  'Getting',
# ...

# %%
exclude=['ERROR','IN','WEBPAGE',':','+','Getting','Images','DONE','U','FUCKING','DUMBASS']
final_list=[i for i in list1 if i not in exclude]

# %%
len(final_list[::2])
# Out:
# 31

# %%
31+378
# Out:
# 409

# %%
# !pip3 install torch torchvision torchaudio
# !pip install easyocr

# %%
import easyocr 
reader=easyocr.Reader(['en'])
img_path="/Users/aryansood/aims/nlp grup1/images/B07BDNGTYC.jpg"
result=reader.readtext(img_path)
print([i[1] for i in result])
# Out:
# ['Yarachute', '100% Pure', 'Coconut Oil']
