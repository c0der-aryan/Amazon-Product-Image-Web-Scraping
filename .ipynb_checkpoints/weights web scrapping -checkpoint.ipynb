# %%
import pandas as pd 
import numpy as np

# %%
from selenium import webdriver
website='https://www.amazon.in/dp/B07BDNCTFC'
path='/Users/aryansood/chromedriver-mac-arm64/chromedriver'
driver=webdriver.Chrome()
driver.get(website)
driver.quit()

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By

def get_amazon_product_weight(url):
    # Set up the Chrome driver (you need to specify the path to your chromedriver executable)
    driver = webdriver.Chrome()

    try:
        # Navigate to the Amazon product page
        driver.get(url)

        # Define the XPath for the element containing the weight information
        # Update the XPath based on the actual HTML structure of the Amazon page
        xpath_expression = '//*[@id="productDetails_techSpec_section_1"]/tbody/tr[1]/td[2]'

        # Find the weight element using the XPath
        weight_element = driver.find_element(By.XPATH, xpath_expression)

        # Get the text content of the element
        weight = weight_element.text.strip()

        return weight

    finally:
        # Close the browser window
        driver.quit()

# Example usage
amazon_url = "https://www.amazon.in/dp/B07BDNCTFC"
product_weight = get_amazon_product_weight(amazon_url)
print(f"Product Weight: {product_weight}")
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Cell In[13], line 30
#      28 # Example usage
#      29 amazon_url = "https://www.amazon.in/dp/B07BDNCTFC"
# ---> 30 product_weight = get_amazon_product_weight(amazon_url)
#      31 print(f"Product Weight: {product_weight}")
#
# Cell In[13], line 17, in get_amazon_product_weight(url)
#      14 xpath_expression = '//*[@id="productDetails_techSpec_section_1"]/tbody/tr[1]/td[2]'
#      16 # Find the weight element using the XPath
# ---> 17 weight_element = driver.find_element(By.XPATH, xpath_expression)
#      19 # Get the text content of the element
#      20 weight = weight_element.text.strip()
#
# File ~/anaconda3/lib/python3.11/site-packages/selenium/webdriver/remote/webdriver.py:742, in WebDriver.find_element(self, by, value)
#     739     by = By.CSS_SELECTOR
#     740     value = f'[name="{value}"]'
# --> 742 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# File ~/anaconda3/lib/python3.11/site-packages/selenium/webdriver/remote/webdriver.py:348, in WebDriver.execute(self, driver_command, params)
#     346 response = self.command_executor.execute(driver_command, params)
#     347 if response:
# --> 348     self.error_handler.check_response(response)
#     349     response["value"] = self._unwrap_value(response.get("value", None))
#     350     return response
#
# File ~/anaconda3/lib/python3.11/site-packages/selenium/webdriver/remote/errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"xpath","selector":"//*[@id="productDetails_techSpec_section_1"]/tbody/tr[1]/td[2]"}
#   (Session info: chrome=120.0.6099.109); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#no-such-element-exception
# Stacktrace:
# 0   chromedriver                        0x00000001006004cc chromedriver + 4162764
# 1   chromedriver                        0x00000001005f8654 chromedriver + 4130388
# 2   chromedriver                        0x000000010024fbc0 chromedriver + 293824
# 3   chromedriver                        0x0000000100296040 chromedriver + 581696
# 4   chromedriver                        0x00000001002d5ab0 chromedriver + 842416
# 5   chromedriver                        0x00000001002896bc chromedriver + 530108
# 6   chromedriver                        0x000000010028a930 chromedriver + 534832
# 7   chromedriver                        0x00000001005c5df8 chromedriver + 3923448
# 8   chromedriver                        0x00000001005ca3cc chromedriver + 3941324
# 9   chromedriver                        0x00000001005ae028 chromedriver + 3825704
# 10  chromedriver                        0x00000001005caf2c chromedriver + 3944236
# 11  chromedriver                        0x00000001005a06e4 chromedriver + 3770084
# 12  chromedriver                        0x00000001005e7970 chromedriver + 4061552
# 13  chromedriver                        0x00000001005e7ae8 chromedriver + 4061928
# 14  chromedriver                        0x00000001005f82d4 chromedriver + 4129492
# 15  libsystem_pthread.dylib             0x0000000185c6bfa8 _pthread_start + 148
# 16  libsystem_pthread.dylib             0x0000000185c66da0 thread_start + 8

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service as ChromeService
from selenium.webdriver.chrome.options import Options as ChromeOptions

def get_amazon_product_weight(url):
    # Set up Chrome options
    chrome_options = ChromeOptions()
    chrome_options.add_argument('--headless')  # Run Chrome in headless mode (without GUI)

    # Set up the Chrome driver (you need to specify the path to your chromedriver executable)
    service = ChromeService()
    driver = webdriver.Chrome(service=service, options=chrome_options)

    try:
        # Navigate to the Amazon product page
        driver.get(url)

        # Wait for the page to load (you might need to adjust the wait time based on your network speed)
        driver.implicitly_wait(10)

        # Define the XPath for the element containing the weight information
        # Update the XPath based on the actual HTML structure of the Amazon page
#         xpath_expression = '//*[@id="productDetails_techSpec_section_1"]/tbody/tr[1]/td[2]'
#         xpath_expression= '//*[@id="productDetails_techSpec_section_1"]/tbody/tr[10]/td[1]'
        xpath_expression= '//*[@id="productDetails_detailBullets_sections1"]/tbody/tr[7]'
        # Find the weight element using the XPath
        weight_element = driver.find_element(By.XPATH, xpath_expression)

        # Get the text content of the element
        weight = weight_element.text.strip()

        return weight

    finally:
        # Close the browser window
        driver.quit()

# Example usage
amazon_url = "https://www.amazon.in/dp/B07BDNCTFC"
product_weight = get_amazon_product_weight(amazon_url)
print(f"Product Weight: {product_weight}")
# Out:
# Product Weight: Item Weight 290 g

# %%
file_path = 'Data Input (Test & Train).xlsx'
sheet_name = 'Test_India'
df = pd.read_excel(file_path, sheet_name, header=1)
col = 'URL'
for i in df[col]:
    print(i)
    try :
        print(get_amazon_product_weight(i))
    except : 
        print("na")
# Out:
# https://www.amazon.in/dp/B08ZJXVL6D
# na
# https://www.amazon.in/dp/B0B6W5KCRM
# Best Sellers Rank #36 in Beauty (See Top 100 in Beauty)
# #5 in Hair Oils
# https://www.amazon.in/dp/B07BDNGTYC
# Generic Name Coconut Oil Bottle
# https://www.amazon.in/dp/B07K2JHVRY
# Generic Name hair oil
# https://www.amazon.in/dp/B07DD2RZS4
# na
# https://www.amazon.in/dp/B07NDR2J4K
# Generic Name Onion Black Seed Hair Oil - Controls Hair Fall - No Mineral Oil & Silicones
# https://www.amazon.in/dp/B0832ZWDHR
# na
# https://www.amazon.in/dp/B07BDNCTFC
# Item Weight 290 g
# https://www.amazon.in/dp/B002ZVG95W
# Generic Name hair oil
# https://www.amazon.in/dp/B085RMP876
# na
# https://www.amazon.in/dp/B07W7CTLD1
# na
# https://www.amazon.in/dp/B07BZN59BS
# Generic Name castor oil
# https://www.amazon.in/dp/B01412X46Y
# Generic Name hair oil
# https://www.amazon.in/dp/B008E7Q0G4
# Generic Name Bajaj Almond Drops Hair Oil 500ml
# https://www.amazon.in/dp/B08PGDPPM4
# Included Components Light Liquid Paraffin (76.8%), Mustard Oil including sweet almond oil (21%), Perfume, Vit. E Acetate, TBHQ, CI 47000, CI 26100, Type 3 Hair Oil
# https://www.amazon.in/dp/B07GWY28FZ
# na
# https://www.amazon.in/dp/B09J5C7J7L
# na
# https://www.amazon.in/dp/B003NQESIS
# na
# https://www.amazon.in/dp/B07BG1TX99
# na
# https://www.amazon.in/dp/B0B38NZYXN
# na
# https://www.amazon.in/dp/B082CXT58C
# na
# https://www.amazon.in/dp/B013UPR9IC
# na
# https://www.amazon.in/dp/B013UQ11JE
# na
# https://www.amazon.in/dp/B08598G2Q8
# na
# https://www.amazon.in/dp/B0BH4BV1VL
# na
# https://www.amazon.in/dp/B004C1VIPY
# na
# https://www.amazon.in/dp/B004D1PDLS
# Generic Name Bajaj Almond Drops Hair Oil 300ml
# https://www.amazon.in/dp/B01MFGFSYS
# Generic Name Hair Oil
# https://www.amazon.in/dp/B009SOS7ZE
# Generic Name Badam Oil
# https://www.amazon.in/dp/B07BG39GVC
# Best Sellers Rank #60 in Beauty (See Top 100 in Beauty)
# #8 in Hair Oils
# https://www.amazon.in/dp/B0928X4Y6G
# Generic Name Virgin Coconut oil
# https://www.amazon.in/dp/B09SLWMVCL
# Best Sellers Rank #674 in Beauty (See Top 100 in Beauty)
# #44 in Hair Oils
# https://www.amazon.in/dp/B072N2CBBP
# na
# https://www.amazon.in/dp/B07MSHC5FZ
# Best Sellers Rank #260 in Beauty (See Top 100 in Beauty)
# #18 in Hair Oils
# https://www.amazon.in/dp/B0824B9GLL
# Generic Name Ayurvedic Hot-Oil
# https://www.amazon.in/dp/B00U8TQIY0
# Generic Name Hair Oil
# https://www.amazon.in/dp/B074MJ3VX8
# Best Sellers Rank #334 in Beauty (See Top 100 in Beauty)
# #22 in Hair Oils
# https://www.amazon.in/dp/B09N9T3RPY
# Generic Name Castor oil
# https://www.amazon.in/dp/B0828TBY68
# na
# https://www.amazon.in/dp/B07RDNNDXN
# Best Sellers Rank #260 in Beauty (See Top 100 in Beauty)
# #18 in Hair Oils
# https://www.amazon.in/dp/B0B4WWLNF1
# Best Sellers Rank #2,717 in Beauty (See Top 100 in Beauty)
# #113 in Hair Oils
# https://www.amazon.in/dp/B07Y2BT66G
# Best Sellers Rank #1,132 in Beauty (See Top 100 in Beauty)
# #62 in Hair Oils
# https://www.amazon.in/dp/B09N97MGB9
# na
# https://www.amazon.in/dp/B08CK5M4WM
# Best Sellers Rank #3,034 in Beauty (See Top 100 in Beauty)
# #122 in Hair Oils
# https://www.amazon.in/dp/B07Y53R164
# Best Sellers Rank #1,853 in Beauty (See Top 100 in Beauty)
# #90 in Hair Oils
# https://www.amazon.in/dp/B003O7DXLO
# na
# https://www.amazon.in/dp/B0BZYYS8H9
# na
# https://www.amazon.in/dp/B0063OQJJI
# Generic Name Hair Oil
# https://www.amazon.in/dp/B07KSW7X5G
# Generic Name 100% Pure and Natural Oilve Oil
# https://www.amazon.in/dp/B008DY631U
# na
# https://www.amazon.in/dp/B0BW766L2Q
# na
# https://www.amazon.in/dp/B006G84LGE
# Included Components Hair oil 1 unit 200ML
# https://www.amazon.in/dp/B09QKNHJNC
# na
# https://www.amazon.in/dp/B0BC9DRR7H
# Generic Name oil
# https://www.amazon.in/dp/B0BKNZN1SN
# Generic Name oil
# https://www.amazon.in/dp/B0BHW1Y88Q
# na
# https://www.amazon.in/dp/B00GMC02XK
# na
# https://www.amazon.in/dp/B01N1Z7A03
# Best Sellers Rank #1,312 in Beauty (See Top 100 in Beauty)
# #68 in Hair Oils
# https://www.amazon.in/dp/B07CJ33NLC
# na
# https://www.amazon.in/dp/B08JR2SGJL
# na
# https://www.amazon.in/dp/B0982CQFPT
# Generic Name Hair Oil
# https://www.amazon.in/dp/B07ZKV6L4Q
# Generic Name Aloe Vera Enriched Coconut Hair Oil
# https://www.amazon.in/dp/B0842MJKQ4
# Best Sellers Rank #2,778 in Beauty (See Top 100 in Beauty)
# #117 in Hair Oils
# https://www.amazon.in/dp/B01HRXK2DC
# Generic Name Facewash
# https://www.amazon.in/dp/B0B283MT3P
# Best Sellers Rank #63 in Beauty (See Top 100 in Beauty)
# #9 in Hair Oils
# https://www.amazon.in/dp/B0B12MBSF9
# Best Sellers Rank #1,150 in Beauty (See Top 100 in Beauty)
# #63 in Hair Oils
# https://www.amazon.in/dp/B07F5NCTN2
# Generic Name Oil
# https://www.amazon.in/dp/B07DHGLKBW
# Best Sellers Rank #1,938 in Beauty (See Top 100 in Beauty)
# #89 in Hair Oils
# https://www.amazon.in/dp/B008KH6DDI
# Included Components Label, shrink wrap, carton
# https://www.amazon.in/dp/B09DS8BR7H
# na
# https://www.amazon.in/dp/B0BQRKZK7N
# Best Sellers Rank #19 in Beauty (See Top 100 in Beauty)
# #1 in Hair Regrowth Treatments
# #3 in Hair Oils
# #4 in Body Washes (Beauty)
# https://www.amazon.in/dp/B00A8VQ5D2
# Item Dimensions LxWxH 40 x 40 x 122 Millimeters
# https://www.amazon.in/dp/B06VY94QPV
# Best Sellers Rank #1,961 in Beauty (See Top 100 in Beauty)
# #91 in Hair Oils
# https://www.amazon.in/dp/B00CBRHYKO
# Generic Name oil
# https://www.amazon.in/dp/B0BLKHG5BM
# na
# https://www.amazon.in/dp/B07N87S9T8
# Best Sellers Rank #2,097 in Beauty (See Top 100 in Beauty)
# #94 in Hair Oils
# https://www.amazon.in/dp/B07WLDJS3L
# Generic Name Gold Coconut Hair Oil
# https://www.amazon.in/dp/B08B2N5JNS
# na
# https://www.amazon.in/dp/B004CRY5G2
# Generic Name Bajaj Brahmi Amla Hair Oil 300ml
# https://www.amazon.in/dp/B07P5L94Z6
# na
# https://www.amazon.in/dp/B082MJTZ35
# na
# https://www.amazon.in/dp/B08B2RMD3V
# na
# https://www.amazon.in/dp/B013UT2PJQ
# na
# https://www.amazon.in/dp/B0BT9WN6KC
# Best Sellers Rank #3,297 in Beauty (See Top 100 in Beauty)
# #134 in Hair Oils
# https://www.amazon.in/dp/B099BNGMW7
# na
# https://www.amazon.in/dp/B09SLW3P71
# na
# https://www.amazon.in/dp/B0BJX8MHXW
# na
# https://www.amazon.in/dp/B09WLZJG7M
# Best Sellers Rank #4,222 in Beauty (See Top 100 in Beauty)
# #168 in Hair Oils
# https://www.amazon.in/dp/B00AF73C6M
# Included Components Label, shrink wrap, carton
# https://www.amazon.in/dp/B08S34BGPY
# na
# https://www.amazon.in/dp/B0BD8R1491
# Best Sellers Rank #2,691 in Beauty (See Top 100 in Beauty)
# #112 in Hair Oils
# https://www.amazon.in/dp/B078S925BY
# Included Components 1 Bottle Of Hair/Skin Oil
# https://www.amazon.in/dp/B09C8DC2KM
# Best Sellers Rank #40,495 in Beauty (See Top 100 in Beauty)
# #17 in 2-in-1 Shampoo & Conditioner
# #32 in Hair Care Sets
# #141 in Hair Creams, Gels & Lotions
# https://www.amazon.in/dp/B08P2TPB7Q
# Included Components Hair Oil Bottle
# https://www.amazon.in/dp/B07JLP5J13
# Generic Name Hair Oil
# https://www.amazon.in/dp/B0B299J14J
# Best Sellers Rank #362 in Beauty (See Top 100 in Beauty)
# #23 in Hair Oils
# https://www.amazon.in/dp/B09RPQWC7L
# Generic Name Hair Oil
# https://www.amazon.in/dp/B0BCFN5C6P
# na
# https://www.amazon.in/dp/B07RDJHPZS
# Included Components Ramakrishna Vidyut Ayurved Pharmacy Maka Mahabhringaraj Oil, 500 ML
# https://www.amazon.in/dp/B08RP3Z9ZS
# na
# https://www.amazon.in/dp/B09RSKMZ9N
# na
# https://www.amazon.in/dp/B09DSKCNL1
# na
# https://www.amazon.in/dp/B09VT2M9N6
# Best Sellers Rank #2,980 in Beauty (See Top 100 in Beauty)
# #121 in Hair Oils
# https://www.amazon.in/dp/B086QDT64L
# na
# https://www.amazon.in/dp/B00S850C5C
# Best Sellers Rank #43 in Beauty (See Top 100 in Beauty)
# #7 in Hair Oils
# https://www.amazon.in/dp/B08N7RD3GM
# na
# https://www.amazon.in/dp/B07HHMY49R
# Generic Name hair oil
# https://www.amazon.in/dp/B0BJ792V2D
# Best Sellers Rank #2,097 in Beauty (See Top 100 in Beauty)
# #94 in Hair Oils
# https://www.amazon.in/dp/B00CBRHLJ8
# Best Sellers Rank #321 in Beauty (See Top 100 in Beauty)
# #20 in Hair Oils
# https://www.amazon.in/dp/B08JR3V8JK
# na
# https://www.amazon.in/dp/B0B12PMQ7V
# Best Sellers Rank #1,150 in Beauty (See Top 100 in Beauty)
# #63 in Hair Oils
# https://www.amazon.in/dp/B0BCH411HY
# na
# https://www.amazon.in/dp/B01GCB8700
# na
# https://www.amazon.in/dp/B00M711DFQ
# Best Sellers Rank #1,910 in Beauty (See Top 100 in Beauty)
# #88 in Hair Oils
# https://www.amazon.in/dp/B08P2NSS15
# Included Components Hair Oil Bottle
# https://www.amazon.in/dp/B08QVCTQQ6
# na
# https://www.amazon.in/dp/B06XYRXJVB
# Generic Name Active Hair Oil
# https://www.amazon.in/dp/B0B5TQX3NX
# na
# https://www.amazon.in/dp/B00LEKJGZU
# Generic Name Badam Oil
# https://www.amazon.in/dp/B00SUTAE6S
# na
# https://www.amazon.in/dp/B0B2918K5R
# Best Sellers Rank #376 in Beauty (See Top 100 in Beauty)
# #24 in Hair Oils
# https://www.amazon.in/dp/B07TFPJ4KY
# Item Dimensions LxWxH 75 x 97 x 224 Centimeters
# https://www.amazon.in/dp/B083DYC5PY
# Best Sellers Rank #6,370 in Beauty (See Top 100 in Beauty)
# #278 in Hair Oils
# https://www.amazon.in/dp/B07SNF6KP1
# Best Sellers Rank #362 in Beauty (See Top 100 in Beauty)
# #23 in Hair Oils
# https://www.amazon.in/dp/B0BQR3FTHH
# Best Sellers Rank #43,580 in Beauty (See Top 100 in Beauty)
# #1,707 in Hair Oils
# https://www.amazon.in/dp/B07RTPG5MX

# %%
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.chrome.service import Service as ChromeService
from selenium.webdriver.chrome.options import Options as ChromeOptions

def get_amazon_product_weight(url):
    # Set up Chrome options
    chrome_options = ChromeOptions()
    chrome_options.add_argument('--headless')  # Run Chrome in headless mode (without GUI)

    # Set up the Chrome driver (you need to specify the path to your chromedriver executable)
    service = ChromeService()
    driver = webdriver.Chrome(service=service, options=chrome_options)

    try:
        # Navigate to the Amazon product page
        driver.get(url)

        # Wait for the page to load (you might need to adjust the wait time based on your network speed)
        driver.implicitly_wait(10)

        # Define the XPath for the element containing the weight information
        # Update the XPath based on the actual HTML structure of the Amazon page
#         xpath_expression = '//*[@id="productDetails_techSpec_section_1"]/tbody/tr[1]/td[2]'
#         xpath_expression= '//*[@id="productDetails_techSpec_section_1"]/tbody/tr[10]/td[1]'
        xpath_expression= '//*[@id="productDetails_detailBullets_sections1"]/tbody/tr[7]'
        # Find the weight element using the XPath
        weight_element = driver.find_element(By.XPATH, xpath_expression)
        
        rows = driver. find_elements_by_tag_name('tr')
        for match in matches:
        print (match. text)
        # driver.quit ()

        # Get the text content of the element
        weight = weight_element.text.strip()

        return weight

    finally:
        # Close the browser window
        driver.quit()

# Example usage
amazon_url = "https://www.amazon.in/dp/B07BDNCTFC"
product_weight = get_amazon_product_weight(amazon_url)
print(f"Product Weight: {product_weight}")

# %%
# Set up Chrome options
chrome_options = ChromeOptions()
chrome_options.add_argument('--headless')  # Run Chrome in headless mode (without GUI)

# Set up the Chrome driver (you need to specify the path to your chromedriver executable)
service = ChromeService()
driver = webdriver.Chrome(service=service, options=chrome_options)

try:
    # Navigate to the Amazon product page
    driver.get(url)

    # Wait for the page to load (you might need to adjust the wait time based on your network speed)
    driver.implicitly_wait(10)

    # Define the XPath for the element containing the weight information
    # Update the XPath based on the actual HTML structure of the Amazon page
    xpath_expression= '//*[@id="productDetails_detailBullets_sections1"]/tbody/tr[7]'
    # Find the weight element using the XPath
    weight_element = driver.find_element(By.XPATH, xpath_expression)
        
    rows = driver. find_elements_by_tag_name('tr')
    for match in matches:
        print (match. text)
    
finally:
    # Close the browser window
    driver.quit()
